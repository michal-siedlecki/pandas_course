# %% [markdown]
# ## S06-L007 - przetwarzanie obiektu grupy

# %%
import numpy as np
import pandas as pd
from datetime import datetime
from datetime import timedelta
import time

# %%
df = pd.read_csv('course-files/marathon_results_2016.csv', index_col='Bib',
usecols=['Bib','40K','Half','Pace','Age','M/F','Country','State','City'])
df['40K'] = df['40K'].apply(pd.to_timedelta)
df['Half'] = df['Half'].apply(pd.to_timedelta)
df['TotalSeconds'] = df['40K'].apply(lambda x: timedelta.total_seconds(x))
df['HalfSeconds'] = df['Half'].apply(lambda x: timedelta.total_seconds(x))
df.head()
# Out:
#      Age M/F         City State Country     Half      40K     Pace  \
# Bib
# 5     21   M  Addis Ababa   NaN     ETH 01:06:45 02:05:59  0:05:04
# 1     26   M         Ambo   NaN     ETH 01:06:46 02:05:59  0:05:06
# 6     31   M  Addis Ababa   NaN     ETH 01:06:44 02:06:47  0:05:07
# 11    33   M       Kitale   NaN     KEN 01:06:46 02:06:47  0:05:07
# 14    23   M      Eldoret   NaN     KEN 01:06:46 02:08:11  0:05:11
#
#      TotalSeconds  HalfSeconds
# Bib
# 5          7559.0       4005.0
# 1          7559.0       4006.0
# 6          7607.0       4004.0
# 11         7607.0       4006.0
# 14         7691.0       4006.0

# %%
group_city = df.groupby(by='City')

# %%
for city, data in group_city:
    print(city, data.loc[data['TotalSeconds'].idxmin()])
# Out:
# 0851 Oslo Age                          39
# M/F                           F
# City                  0851 Oslo
# State                       NaN
# Country                     NOR
# Half            0 days 01:35:31
# 40K             0 days 03:15:24
# Pace                    0:07:55
# TotalSeconds              11724
# HalfSeconds                5731
# Name: 6229, dtype: object
# 20832 Age                          35
# M/F                           M
# City                      20832
# State                        MD
# Country                     USA
# Half            0 days 01:35:57
# 40K             0 days 03:14:00
# Pace                    0:07:51
# TotalSeconds              11640
# HalfSeconds                5757
# Name: 4186, dtype: object
# 34-120 Andrychow Age                           44
# M/F                            F
# City            34-120 Andrychow
# State                        NaN
# Country                      POL
# Half             0 days 01:58:39
# ...

# %%
best_per_city = pd.DataFrame()

# %%
for city, data in group_city:
    best_per_city = best_per_city.append(data.loc[data['TotalSeconds'].idxmin()])

# %%
best_per_city
# Out:
#            40K   Age              City Country     Half  HalfSeconds M/F  \
# 6229  03:15:24  39.0         0851 Oslo     NOR 01:35:31       5731.0   F
# 4186  03:14:00  35.0             20832     USA 01:35:57       5757.0   M
# 31786 03:55:09  44.0  34-120 Andrychow     POL 01:58:39       7119.0   F
# 15350 03:44:58  58.0    5700 Svendborg     DEN 01:49:12       6552.0   M
# 20668 03:37:23  46.0             95630     USA 01:50:25       6625.0   F
# ...        ...   ...               ...     ...      ...          ...  ..
# 2978  03:03:15  42.0            Zurich     SUI 01:32:09       5529.0   M
# 31756 04:56:52  58.0      Zweibruecken     GER 02:22:22       8542.0   F
# 31280 04:42:02  61.0          Zwevegem     BEL 02:15:30       8130.0   M
# 4052  03:04:11  46.0            Zwolle     NED 01:33:21       5601.0   M
# 1507  02:45:08  32.0           hingham     USA 01:24:38       5078.0   M
#
#           Pace State  TotalSeconds
# 6229   0:07:55   NaN       11724.0
# ...
