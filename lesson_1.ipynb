# %%
from datetime import datetime

birthday = datetime(1987, 7, 8, 0, 0, 0)
difference = datetime.today() - birthday

print(difference.days)
# Out:
# 11768

# %%
import pandas as pd

mon = pd.Series(list(x for x in range(200) if x%3 == 0))

newmon = mon.mul(12)

print(mon)
print()
print(newmon)
# Out:
# 0       0
# 1       3
# 2       6
# 3       9
# 4      12
# 5      15
# 6      18
# 7      21
# 8      24
# 9      27
# 10     30
# 11     33
# 12     36
# 13     39
# 14     42
# 15     45
# 16     48
# 17     51
# 18     54
# 19     57
# 20     60
# 21     63
# 22     66
# 23     69
# 24     72
# 25     75
# 26     78
# 27     81
# 28     84
# 29     87
#      ...
# 37    111
# 38    114
# 39    117
# 40    120
# 41    123
# 42    126
# 43    129
# 44    132
# 45    135
# 46    138
# 47    141
# 48    144
# 49    147
# 50    150
# 51    153
# 52    156
# 53    159
# 54    162
# 55    165
# 56    168
# 57    171
# 58    174
# 59    177
# 60    180
# 61    183
# 62    186
# 63    189
# 64    192
# 65    195
# 66    198
# Length: 67, dtype: int64
#
# 0        0
# 1       36
# 2       72
# 3      108
# 4      144
# 5      180
# 6      216
# 7      252
# 8      288
# 9      324
# 10     360
# 11     396
# 12     432
# 13     468
# 14     504
# 15     540
# 16     576
# 17     612
# ...

# %%
countries = ['USA', 'Spain', 'Poland', 'Portugal', 'Italy']
currencies = ['USD', 'EUR', 'PLN', 'EUR', 'EUR']



countrySeries = pd.Series(countries, currencies)

countrySeries.ToList()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-70645167ffc6> in <module>
#       6 countrySeries = pd.Series(countries, currencies)
#       7
# ----> 8 countrySeries.ToList()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'ToList'
