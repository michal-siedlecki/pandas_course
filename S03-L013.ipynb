# %% [markdown]
# ## S03-L013-LAB Duplikaty w data frame

# %%
import pandas as pd
import numpy as np

# %%
surveys = pd.read_csv('course-files/StackOverflowDeveloperSurvey2018.csv', low_memory=False, \
                      usecols=['Country','Gender','OperatingSystem'])

# %%
surveys['Country'].is_unique
# Out:
# False

# %%
surveys['Country'].head()
# Out:
# 0             Kenya
# 1    United Kingdom
# 2     United States
# 3     United States
# 4      South Africa
# Name: Country, dtype: object

# %%
surveys['Country'].nunique()
# Out:
# 183

# %%
len(surveys['Country'].unique())
# Out:
# 184

# %%
duplicateKeepFirst = surveys['Country'].duplicated(keep="first")
duplicateKeepFirst.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: Country, dtype: bool

# %%
surveys[~duplicateKeepFirst].head(10)
# Out:
#            Country OperatingSystem  Gender
# 0            Kenya     Linux-based    Male
# 1   United Kingdom     Linux-based    Male
# 2    United States             NaN     NaN
# 4     South Africa         Windows    Male
# 7          Nigeria         Windows  Female
# 9            India             NaN     NaN
# 10           Spain             NaN     NaN
# 12         Croatia             NaN     NaN
# 14     Netherlands         Windows    Male
# 15          Israel             NaN     NaN

# %%
len(surveys[~duplicateKeepFirst])
# Out:
# 184

# %%
int(surveys[~duplicateKeepFirst].size/len(surveys.columns))
# Out:
# 184

# %%
surveys.query('Country == "Poland"')['OperatingSystem'].value_counts()/len(surveys.query('Country == "Poland"'))
# Out:
# Windows        0.397267
# Linux-based    0.212535
# MacOS          0.141847
# BSD/Unix       0.001414
# Name: OperatingSystem, dtype: float64

# %%
surveys['OperatingSystem'].value_counts()/len(surveys)
# Out:
# Windows        0.384624
# MacOS          0.205604
# Linux-based    0.178888
# BSD/Unix       0.001497
# Name: OperatingSystem, dtype: float64

# %%
surveys.drop_duplicates(subset=['OperatingSystem', 'Country'], inplace=True)

# %%
surveys.query('Country == "Poland"')
# Out:
#       Country OperatingSystem Gender
# 30     Poland     Linux-based   Male
# 34     Poland         Windows   Male
# 232    Poland             NaN    NaN
# 854    Poland           MacOS   Male
# 72587  Poland        BSD/Unix    NaN
