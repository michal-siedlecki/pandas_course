# %% [markdown]
# ## S02-L009 - Standardowe metody Pythona a obiekty PANDAS

# %%
import matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %matplotlib inline

salary = pd.read_csv('StackOverflowDeveloperSurvey.csv', usecols=['Salary'], squeeze=True)
salary.dropna(inplace=True)
salary.head()
# Out:
# 2     113750.0
# 14    100000.0
# 17    130000.0
# 18     82500.0
# 22    100764.0
# Name: Salary, dtype: float64

# %%
len(salary)
# Out:
# 12891

# %%
min(salary)
# Out:
# 0.0

# %%
max(salary)
# Out:
# 197000.0

# %%
list(salary.head())
# Out:
# [113750.0, 100000.0, 130000.0, 82500.0, 100764.0]

# %%
listSalarySorted = sorted(list(salary), reverse=True)

# %%
salary.name = 'Salary of a person'

# %%
salary.head()
# Out:
# 2     113750.0
# 14    100000.0
# 17    130000.0
# 18     82500.0
# 22    100764.0
# Name: Salary of a person, dtype: float64
