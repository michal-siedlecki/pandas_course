# %% [markdown]
# ## S02-L003-LAB Korzystanie z modulow

# %%
import matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %matplotlib inline

weekdays = np.array(['monday', 'tuesday', 'wendesday', 'thursday', 'friday', 'saturday', 'sunday'])
freedays = np.array([False, False, False, False, False, True, True])

freeDaySeries = pd.Series(freedays, weekdays)

freeDaySeries
# Out:
# monday       False
# tuesday      False
# wendesday    False
# thursday     False
# friday       False
# saturday      True
# sunday        True
# dtype: bool

# %%
holidays = {
    'New Year' : '2018-01-01',
    'Epiphany' : '2018-01-06',
    'Easter' : '2018-04-01'
}

holidaySeries = pd.Series(holidays)
holidaySeries
# Out:
# New Year    2018-01-01
# Epiphany    2018-01-06
# Easter      2018-04-01
# dtype: object
