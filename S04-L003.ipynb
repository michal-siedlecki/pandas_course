# %% [markdown]
# ## S04-L003-Dodawanie i usuwanie wierszy

# %%
import pandas as pd
import numpy as np

# %%
professions = pd.read_csv('course-files/Prestige.csv')

# %%
professions.head()
# Out:
#                   name  education  income  women  prestige  census  type
# 0   gov.administrators      13.11   12351  11.16      68.8    1113  prof
# 1     general.managers      12.26   25879   4.02      69.1    1130  prof
# 2          accountants      12.77    9271  15.70      63.4    1171  prof
# 3  purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# 4             chemists      14.62    8403  11.68      73.5    2111  prof

# %%
list(professions.columns)
# Out:
# ['name', 'education', 'income', 'women', 'prestige', 'census', 'type']

# %%
dictionary = {x:np.NaN for x in list(professions.columns)}

# %%
print(dictionary)
# Out:
# {'name': nan, 'education': nan, 'income': nan, 'women': nan, 'prestige': nan, 'census': nan, 'type': nan}

# %%
dictionary['name'] = 'data_scientist'
dictionary
# Out:
# {'census': nan,
#  'education': nan,
#  'income': nan,
#  'name': 'data_scientist',
#  'prestige': nan,
#  'type': nan,
#  'women': nan}

# %%
professions = professions.append(dictionary, ignore_index=True)

# %%
professions.tail()
# Out:
#                name  education  income  women  prestige  census type
# 98     taxi.drivers       7.93  4224.0   3.59      25.1  9173.0   bc
# 99     longshoremen       8.37  4753.0   0.00      26.1  9313.0   bc
# 100     typesetters      10.00  6462.0  13.58      42.2  9511.0   bc
# 101     bookbinders       8.55  3617.0  70.87      35.2  9517.0   bc
# 102  data_scientist        NaN     NaN    NaN       NaN     NaN  NaN

# %%
professions
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-ad156423c293> in <module>()
# ----> 1 professions.iloc['taxi.drivers']
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2152             key = item_from_zerodim(key)
#    2153             if not is_integer(key):
# -> 2154                 raise TypeError("Cannot index by location index with a non-integer key")
#    2155
#    2156             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key
