# %% [markdown]
# ## S02-L005 - LAB - Metody Data Series

# %%
import matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %matplotlib inline

cities = np.array(['Shanghai', 'Beijing', 'Istanbul'])
population = np.array([24183300, 20794100, 15030000])

citypop = pd.Series(population, cities)

citypop
# Out:
# Shanghai    24183300
# Beijing     20794100
# Istanbul    15030000
# dtype: int64

# %%
citypop = pd.Series(index = cities, data = population)
citypop
# Out:
# Shanghai    24183300
# Beijing     20794100
# Istanbul    15030000
# dtype: int64

# %%
citypop.sum()
# Out:
# 60007400

# %%
int(citypop.mean())
# Out:
# 20002466

# %%
citypop.index
# Out:
# Index(['Shanghai', 'Beijing', 'Istanbul'], dtype='object')

# %%
citypop.keys()
# Out:
# Index(['Shanghai', 'Beijing', 'Istanbul'], dtype='object')

# %%
citypop.values
# Out:
# array([24183300, 20794100, 15030000])

# %%
citypop.to_numpy()
# Out:
# array([24183300, 20794100, 15030000])
