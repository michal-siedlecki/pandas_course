# %% [markdown]
# ## S02 - L013 - Porównanie metod wyszukiwania danych po indeksie

# %%
import pandas as pd

countries = pd.read_csv('course-files/countries.csv', usecols=['Symbol','Name'], index_col='Symbol', squeeze=True)
countries.head(20)
# Out:
# Symbol
# AF            Afghanistan
# AL                Albania
# DZ                Algeria
# AD                Andorra
# AO                 Angola
# AI               Anguilla
# AQ             Antarctica
# AG    Antigua and Barbuda
# SA           Saudi Arabia
# AR              Argentina
# AM                Armenia
# AW                  Aruba
# AU              Australia
# AT                Austria
# AZ             Azerbaijan
# BS                Bahamas
# BH                Bahrain
# BD             Bangladesh
# BB               Barbados
# BE                Belgium
# Name: Name, dtype: object

# %%
countries.loc['FR']
# Out:
# 'France'

# %%
countries['FR']
# Out:
# 'France'

# %%
countries.at['FR']
# Out:
# 'France'

# %%
countries.ix['FR']
# Out:
# /home/ms/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 'France'

# %%
countries.iat[13]
# Out:
# 'Austria'

# %%
countries.iloc[13]
# Out:
# 'Austria'

# %%
nordic = ["FI", "SE", "NO"]
for symbol in nordic:
    print(countries.get(symbol))
# Out:
# Finland
# Sweden
# Norway

# %%
countries.get(nordic)
# Out:
# Symbol
# FI    Finland
# SE     Sweden
# NO     Norway
# Name: Name, dtype: object

# %%
countries.loc[nordic]
# Out:
# Symbol
# FI    Finland
# SE     Sweden
# NO     Norway
# Name: Name, dtype: object

# %%
mySeries = pd.read_csv('course-files/countries.csv', usecols=['Name'], squeeze=True)
mySeries.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-45cae42ba7a3> in <module>
# ----> 1 mySeries = pd.read_csv('course-files/countries.csv', usecols=['Name'], squeeze=True)
#       2 mySeries.head()
#
# NameError: name 'pd' is not defined
