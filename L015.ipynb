# %% [markdown]
# ## S02 - L015 - Określanie indeksu podczas wczytywania pliku CSV

# %%
import pandas as pd

fortune500 = pd.read_csv('course-files/Fortune_500_2017.csv', usecols=['Rank','Title'], index_col='Rank', squeeze=True)
fortune500.dropna(inplace=True)
fortune500.head(10)
# Out:
# Rank
# 1                Walmart
# 2     Berkshire Hathaway
# 3                  Apple
# 4            Exxon Mobil
# 5               McKesson
# 6     UnitedHealth Group
# 7             CVS Health
# 8         General Motors
# 9                   AT&T
# 10            Ford Motor
# Name: Title, dtype: object

# %%
fortune500.tail(20)
# Out:
# Rank
# 481           Booz Allen Hamilton Holding
# 482                              Chemours
# 483    Western & Southern Financial Group
# 484                              Celanese
# 485                   Windstream Holdings
# 486                              Seaboard
# 487                             Essendant
# 488                                Apache
# 489                                Airgas
# 490                        Kelly Services
# 491                         Liberty Media
# 492                      Rockwell Collins
# 493             Robert Half International
# 494                             CH2M Hill
# 495                              Big Lots
# 496                         Michaels Cos.
# 497                         Toll Brothers
# 498                                 Yahoo
# 499                         Vistra Energy
# 500                        ABM Industries
# Name: Title, dtype: object

# %%
fortune500 = pd.read_csv('course-files/Fortune_500_2017.csv', usecols=['Employees','Title'], index_col='Title', squeeze=True)
fortune500[['IBM','Facebook','Alphabet','Apple']]
# Out:
# Title
# IBM         414400
# Facebook     17048
# Alphabet     72053
# Apple       116000
# Name: Employees, dtype: int64

# %%
fortune500['IBM':'Intel']
# Out:
# Title
# IBM                          414400
# State Farm Insurance Cos.     68234
# Phillips 66                   14800
# Johnson & Johnson            126400
# Procter & Gamble             105000
# Valero Energy                  9996
# Target                       323000
# Freddie Mac                    5982
# Lowe’s                       240000
# Dell Technologies            138000
# MetLife                       58000
# Aetna                         49500
# PepsiCo                      264000
# Archer Daniels Midland        31800
# UPS                          335520
# Intel                        106000
# Name: Employees, dtype: int64

# %%
fortune500['IBM':'Intel'].size
# Out:
# 16

# %%
fortune500['Microsoft']
# Out:
# 114000
