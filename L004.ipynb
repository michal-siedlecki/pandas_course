# %% [markdown]
# ## S02-L004 - LAB - Atrybuty Data Series

# %%
import matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import random as rnd

# %matplotlib inline

dataAsFloatList = np.array([x*rnd.random() for x in list(range(100000))])
dataAsFloatSeries = pd.Series(dataAsFloatList)

dataAsFloatSeries
# Out:
# 0            0.000000
# 1            0.345930
# 2            1.818436
# 3            2.502141
# 4            3.198509
#              ...
# 99995     8935.140729
# 99996     1656.338627
# 99997    91180.794190
# 99998    26462.821992
# 99999    45730.905416
# Length: 100000, dtype: float64

# %%
attrs = [
    
    dataAsFloatSeries.size, 
    dataAsFloatSeries.nbytes, 
    dataAsFloatSeries.shape, 
    dataAsFloatSeries.axes, 
    dataAsFloatSeries.dtype, 
    dataAsFloatSeries.index, 
    dataAsFloatSeries.is_unique, 
    dataAsFloatSeries.is_monotonic
]

for i in attrs:
    print(i)
# Out:
# 100000
# 800000
# (100000,)
# [RangeIndex(start=0, stop=100000, step=1)]
# float64
# RangeIndex(start=0, stop=100000, step=1)
# True
# False

# %%
dataAsStringList = np.array([str(x*rnd.random()) for x in list(range(100000))])
dataAsStringSeries = pd.Series(dataAsStringList)

dataAsStringSeries
# Out:
# 0                       0.0
# 1        0.7749920887679987
# 2        0.6275464567015621
# 3         2.063871149914517
# 4         3.648612172287128
#                 ...
# 99995    16086.981143610756
# 99996     76654.46651247481
# 99997     2864.309148433167
# 99998     81318.24545300024
# 99999     66936.49344977843
# Length: 100000, dtype: object

# %%
attrs = [
    
    dataAsStringSeries.size, 
    dataAsStringSeries.nbytes, 
    dataAsStringSeries.dtype, 
    
]

for i in attrs:
    print(i)
# Out:
# 100000
# 800000
# object

# %%
dataAsFloatSeries.memory_usage(deep=True)
# Out:
# 800128

# %%
dataAsStringSeries.memory_usage(deep=True)
# Out:
# 7434937
