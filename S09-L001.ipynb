# %% [markdown]
# ## S09-L001 - Import

# %%
import pandas as pd
import numpy as np

# %%
url = 'http://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?file=data/\
isoc_cimobi_frq.tsv.gz&unzip=true'

# %%
df = pd.read_csv(url, delimiter='\t')

# %%
df.head()
# Out:
#       indic_is,ind_type,unit,time\geo  EU28  EU27  EU15   EA   BE    BG   CZ   \
# 0       I_IHDDAY,CB_EU_FOR,PC_IND,2012   15    15    16   12   15    : u  : u
# 1   I_IHDDAY,CB_EU_FOR,PC_IND_IU3,2012   21    21    21   17   19    : u  : u
# 2  I_IHDDAY,CB_EU_FOR,PC_IND_IUHD,2012   57    57    57   55   48    : u  : u
# 3       I_IHDDAY,CB_EXT_EU,PC_IND,2012   21    21    22   13   11   25 u   :
# 4   I_IHDDAY,CB_EXT_EU,PC_IND_IU3,2012   28    28    29   19   15   28 u   :
#
#     DK   DE   ...  SI    SK    FI    SE    UK    IS    NO  ME  MK  TR
# 0   22    7   ...  : u  14 u  35 u  35 u   39    16   31 u  :   :   :
# 1   22   11   ...  : u  17 u  36 u  40 u  46 u   17   32 u  :   :   :
# 2  49 u  60   ...  : u   : u   : u   : u  60 u  40 u  50 u  :   :   :
# 3   35   12   ...   3    : u   22    39    39   16 u  32 u  :   :   :
# 4   39   14   ...   5    : u  24 u   42    43   17 u  32 u  :   :   :
#
# [5 rows x 38 columns]

# %%
df_descr = df[df.columns[0]].str.split(',', expand=True)

# %%
df_descr.columns = ['indic_is','ind_type','unit','time_geo']

# %%
df_descr.head()
# Out:
#    indic_is   ind_type         unit time_geo
# 0  I_IHDDAY  CB_EU_FOR       PC_IND     2012
# 1  I_IHDDAY  CB_EU_FOR   PC_IND_IU3     2012
# 2  I_IHDDAY  CB_EU_FOR  PC_IND_IUHD     2012
# 3  I_IHDDAY  CB_EXT_EU       PC_IND     2012
# 4  I_IHDDAY  CB_EXT_EU   PC_IND_IU3     2012

# %%
df = df_descr.join(df)

# %%
df.drop(df.columns[4], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Data columns (total 41 columns):
# indic_is    447 non-null object
# ind_type    447 non-null object
# unit        447 non-null object
# time_geo    447 non-null object
# EU28        447 non-null object
# EU27        447 non-null object
# EU15        447 non-null object
# EA          447 non-null object
# BE          447 non-null object
# BG          447 non-null object
# CZ          447 non-null object
# DK          447 non-null object
# DE          447 non-null object
# EE          447 non-null object
# IE          447 non-null object
# EL          447 non-null object
# ES          447 non-null object
# FR          447 non-null object
# HR          447 non-null object
# IT          447 non-null object
# CY          447 non-null object
# LV          447 non-null object
# LT          447 non-null object
# LU          447 non-null object
# HU          447 non-null object
# MT          447 non-null object
# ...

# %%
url = 'https://examples.opendatasoft.com/explore/dataset/world-heritage-unesco-list/download/?format=json&\
timezone=Europe/Berlin'

# %%
df = pd.read_json(url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 5 columns):
# datasetid           1052 non-null object
# recordid            1052 non-null object
# fields              1052 non-null object
# geometry            1052 non-null object
# record_timestamp    1052 non-null object
# dtypes: object(5)
# memory usage: 41.2+ KB

# %%
df.head()
# Out:
#                     datasetid                                  recordid  \
# 0  world-heritage-unesco-list  ff1f5b718ce2ee87f18dfaf20610f257979f2f4a
# 1  world-heritage-unesco-list  0fd1ad38878a73b01bf59ed430446e098709cea1
# 2  world-heritage-unesco-list  fa66a8d51c28871277f1cdd9c0f2d092a423ff5f
# 3  world-heritage-unesco-list  b16a410e99f603ef138909f6de916de08f0cfdc2
# 4  world-heritage-unesco-list  bb09d483a4ca7411a334314fb13f13301fa51bc0
#
#                                               fields  \
# 0  {'category': 'Cultural', 'short_description_en...
# 1  {'category': 'Natural', 'short_description_en'...
# 2  {'category': 'Cultural', 'short_description_en...
# 3  {'category': 'Cultural', 'short_description_en...
# 4  {'category': 'Natural', 'short_description_en'...
#
#                                             geometry  \
# 0  {'type': 'Point', 'coordinates': [26.69139, 53...
# 1  {'type': 'Point', 'coordinates': [14.996666666...
# ...

# %%
df.iloc[0]['fields']
# Out:
# {'area_hectares': 0.0,
#  'category': 'Cultural',
#  'continent_en': 'Europe and North America',
#  'continent_fr': 'Europe et Amérique du nord',
#  'country_en': 'Belarus',
#  'country_fr': 'Bélarus',
#  'date_inscribed': '2005-01-01',
#  'geographical_coordinates': [53.22278, 26.69139],
# ...
