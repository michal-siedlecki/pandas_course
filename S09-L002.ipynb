# %% [markdown]
# ## S09-L002 - export

# %%
import pandas as pd
import numpy as np

# %%
mcdonalds = pd.read_csv('course-files/Mcdonalds.csv', usecols=['Category', 'Item', 'Calories', 'TotalFat'])

# %%
mcdonalds.to_csv('mc-1.csv', index=False)

# %%
mcdonalds.to_csv('mc-2.csv', index=False, quotechar="\"")

# %%
mcdonalds.to_csv('mc-3.csv', index=False, quotechar="\"", decimal=",")

# %%
mcdonalds.to_csv('mc-4.csv', index=False, quotechar="\"", decimal=",", columns=['Item','TotalFat'])

# %%
mcdonalds.to_json('mc-6.json')

# %%
dads_sandwich = mcdonalds.where(mcdonalds['Item'] == "Big Mac").dropna()

# %%
moms_sandwich = mcdonalds.where(mcdonalds['Item'] == "McChicken").dropna()
moms_fries = mcdonalds.where(mcdonalds['Item'] == "Medium French Fries").dropna()
kids_fries = mcdonalds.where(mcdonalds['Item'] == "Large French Fries").dropna()

# %%
our_menu = dads_sandwich.append(moms_sandwich).append(kids_fries).append(moms_fries)

# %%
our_menu = our_menu.append(kids_fries)

# %%
our_menu['Calories'].sum()/4
# Out:
# 562.5

# %%
our_menu
# Out:
#           Category                 Item  Calories  TotalFat
# 42     Beef & Pork              Big Mac     530.0      27.0
# 66  Chicken & Fish            McChicken     360.0      16.0
# 98  Snacks & Sides   Large French Fries     510.0      24.0
# 97  Snacks & Sides  Medium French Fries     340.0      16.0
# 98  Snacks & Sides   Large French Fries     510.0      24.0

# %%
html = mcdonalds.to_html()

# %%
import io

# %%
with io.open('mc-7.html', mode='w', encoding='utf-8') as f:
    f.write(html)
