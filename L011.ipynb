# %% [markdown]
# ## S02-L011 - Sprawdzanie czy element jest na liście

# %%
import matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %matplotlib inline

countries = pd.read_csv('StackOverflowDeveloperSurvey.csv', usecols=['Country'], squeeze=True)
countries.dropna(inplace=True)
countries.head()
# Out:
# 0     United States
# 1    United Kingdom
# 2    United Kingdom
# 3     United States
# 4       Switzerland
# Name: Country, dtype: object

# %%
'Spain' in countries
# Out:
# False

# %%
'Spain' in countries.values
# Out:
# True

# %%
'Wonderland' in countries.values
# Out:
# False
