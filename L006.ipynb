# %% [markdown]
# ## S02-L006 - LAB - Metody Data Series

# %%
import matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %matplotlib inline


incidents = pd.Series([14,334,312,5823,9491,7486,4343], \
                      ['6', '7-14', '15-17', '18-24', '25-39', '40-59', '60 i więcej'])

incidents
# Out:
# 6                14
# 7-14            334
# 15-17           312
# 18-24          5823
# 25-39          9491
# 40-59          7486
# 60 i więcej    4343
# dtype: int64

# %%
incidents.where(incidents>1000)
# Out:
# 6                 NaN
# 7-14              NaN
# 15-17             NaN
# 18-24          5823.0
# 25-39          9491.0
# 40-59          7486.0
# 60 i więcej    4343.0
# dtype: float64

# %%
incidents.where(incidents>1000).dropna()
# Out:
# 18-24          5823.0
# 25-39          9491.0
# 40-59          7486.0
# 60 i więcej    4343.0
# dtype: float64

# %%
incident1000 = incidents.where(incidents>1000).dropna()
incident1000
# Out:
# 18-24          5823.0
# 25-39          9491.0
# 40-59          7486.0
# 60 i więcej    4343.0
# dtype: float64

# %%
incidents
# Out:
# 6                14
# 7-14            334
# 15-17           312
# 18-24          5823
# 25-39          9491
# 40-59          7486
# 60 i więcej    4343
# dtype: int64

# %%
incidents.filter(items=['18-24', '25-39', '40-59'])
# Out:
# 7600.0

# %%
incidents.where(incidents <= 1000, inplace = True)
incidents.dropna(inplace = True)
incidents
# Out:
# 6         14.0
# 7-14     334.0
# 15-17    312.0
# dtype: float64
